# %% [markdown]
# #설치해야 할 프로그램
# pandas
# scikit-learn
# matplotlib
# mglearn
# #pip install -U 프로그램이름

# %%
# %config InlineBackend.figure_format='retina'

# %%
import pandas as pd
import matplotlib
import numpy as np

# %%
(pd.__version__, matplotlib.__version__, sklearn.__version__, np.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 (pd.__version__, matplotlib.__version__, sklearn.__version__, np.__version__)
#
# NameError: name 'sklearn' is not defined

# %% [markdown]
# ## 데이터 적재

# %%
iris=load_iris()
iris.keys()
iris['target'] #enumerate : 분류의 이름을 숫자로 바꿔놓음
iris['target_names']
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %% [markdown]
# ## 살펴보기

# %% [markdown]
# pandas로 데이터를 합쳐야 하는데 책에서는 합치지 않았음
# 1. size
# 2. 관측자료
# 3. 데이터 타입
# 위의 3가지를 확인해야 한다.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test= train_test_split(iris['data'], iris['target'], random_state=42)

# %%
X_train.shape, y_train.shape
# Out:
# ((112, 4), (112,))

# %%
X_test.shape, y_test.shape
# Out:
# ((38, 4), (38,))

# %% [markdown]
# ## 학습 및 모델

# %%
knn= KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
X_new=np.array([[5,2.9,1,0.2]])
X_new.shape
# Out:
# (1, 4)

# %%
df= pd.DataFrame(iris['data'], columns=iris['feature_names'])
pd.plotting.scatter_matrix(df, figsize=(15,15), cmap='viridis', alpha=.8)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\plotting\_matplotlib\misc.py:96: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax.scatter(
# array([[<Axes: xlabel='sepal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='sepal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='sepal width (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal length (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='petal length (cm)'>],
#        [<Axes: xlabel='sepal length (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='sepal width (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='petal length (cm)', ylabel='petal width (cm)'>,
#         <Axes: xlabel='petal width (cm)', ylabel='petal width (cm)'>]],
#       dtype=object)

# %%
knn.score(X_test,y_test) #print("{:.2f}".format(np.mean(y_pred ==y_test))) 대신 사용하기
# Out:
# 1.0

# %%
prediction=knn.predict(X_new)
print("예측 : ", prediction)
print("예측 타겟 이름 : ", iris['target_names'][prediction]) #iris_datasets를 iris로 선언했으므로 iris로 검색해야 한다.
# Out:
# 예측 :  [0]
# 예측 타겟 이름 :  ['setosa']

# %%
y_pred=knn.predict(X_test)
y_pred
print("{:.2f}".format(np.mean(y_pred ==y_test)))
# Out:
# 1.00

# %% [markdown]
# scikit-learn dataset을 사용해서 문제를 풀 때 target은 숫자로 나타나 있고 정답이라고 볼 수 있다.
# data가 문제로 나온다.
# 머신을 학습시키기 위해서 훈련시킬 문제와 답안지와 테스트할 문제와 답안지를 임의로 균등하게 나누어야 한다.

# %% [markdown]
# ## 평가 및 검증

# %% [markdown]
# <h3>붓꽃 품종 분류</h3>
#
# 분류: 꽃잎+꽃받침=>품종
